# %% [markdown]
# <a href="https://colab.research.google.com/github/jungwonalicia/bigdata/blob/master/%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C%EC%9A%B0_%ED%85%8C%EC%8A%A4%ED%8A%B82_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%9C%A0%EC%82%AC%EC%84%B1_%EC%B0%BE%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import mahotas as mh
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

image = mh.imread('sample_data/scene00.jpg')

plt.figure(figsize=(8,8))
#plt.imszxhow(image)
plt.imshow(image)
plt.show()
